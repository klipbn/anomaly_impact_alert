# %% [markdown]
# # anomaly_impact_alert_example

# %% [markdown]
# Добро пожаловать! Здесь за 10–15 минут покажем, как из обычного временного ряда получить:
#
# - сигналы аномалий
# - прогноз что должно было быть
# - вклад сегментов (platform / country / …) в общую дельту
# - готовое сообщение для бота/дашборда
#
# Что сделаем в ноутбуке
#
# - Сгенерируем (или загрузим) примерный датасет time_at, metric_name, metric_value, platform, country
# - Прогоним ансамбль детекторов (CI/MAD, Z-score, STL/SESD, IsolationForest, LOF)
# - Построим ансамблевый прогноз (Prophet + STL/ETS + Naive) и сравним факт vs. forecast
# - Посчитаем вклады сегментов в общую дельту за день T
#
# Сформируем сообщение для бота в стиле: заголовок → график → цифры → топ-вклады

# %% [markdown]
# pip install anomaly-impact-alert

# %%
# import os
# import sys
# sys.path.append(".")

import numpy as np
import pandas as pd
import sys
import warnings

from datetime import date, datetime, timedelta
from tqdm import tqdm

from anomaly_impact_alert import (
    AnomalyParams,
    analyze_latest_point,
    columns_true,
    ImpactConfig,
    attach_multi_impact,
    BFConfig,
    forecast_values_for_targets_better,
    AlertConfig,
    send_alert_for_date,
    AlertConfig_tg,
    send_alert_for_date_tg,
)

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.float_format", "{:,.2f}".format)
pd.set_option("display.large_repr", "truncate")

# %%
import logging

logging.getLogger("cmdstanpy").disabled = True
logging.getLogger("prophet").setLevel(logging.WARNING)

# %% [markdown]
# ## Исходные данные

# %%
# Здесь синтетический ряд условной метрики Amount

np.random.seed(4242)

dates = pd.date_range("2025-06-01", "2025-11-10", freq="D")

monthly_slopes = {
    (2025, 6): +2.0,
    (2025, 7): -1.0,
    (2025, 8): +4.0,
    (2025, 9): -2.0, 
    (2025,10): +3.0,
    (2025,11): -1.5,
}

weekday_multipliers = {
    0: 0.95,
    1: 1.00,
    2: 1.05,
    3: 1.10,
    4: 1.18,
    5: 0.90,
    6: 0.82,
}

base_level = 1000000.0
values = []
for d in dates:
    slope = monthly_slopes.get((d.year, d.month), 0.0)
    base_level += slope
    weekday_factor = weekday_multipliers[d.weekday()]
    values.append(base_level * weekday_factor)

base = np.array(values, dtype=float)

factors = np.ones(len(dates), dtype=float)


# Тут делаем АНОМАЛИИ :)
anom_sep = {
    "2025-09-05": 0.65,
    "2025-09-17": 0.40,
    "2025-09-26": 1.12,
}
anom_oct = {
    "2025-10-23": 0.75,
    "2025-10-24": 1.1,
}

for ds, v in {**anom_sep, **anom_oct}.items():
    idx = (dates == pd.Timestamp(ds))
    factors[idx] = v

smooth_noise = 1.0 + np.random.normal(0, 0.01, size=len(dates))
signal = base * factors * smooth_noise

platforms = ["web", "android", "ios"]
p_weights = np.array([0.62, 0.28, 0.10])

countries = ["russia", "belarus", "kazakhstan"]
c_weights = np.array([0.74, 0.11, 0.15])

rows = []
for i, d in enumerate(dates):
    total_val = float(signal[i])
    for p, w in zip(platforms, p_weights):
        rows.append([d, "amount", total_val * w, p, "total"])
    for c, w in zip(countries, c_weights):
        rows.append([d, "amount", total_val * w, "total", c])
    rows.append([d, "amount", total_val, "total", "total"])

df = pd.DataFrame(rows, columns=["time_at", "metric_name", "metric_value", "platform", "country"])
df = df.sort_values(["time_at", "platform", "country"]).reset_index(drop=True)

# %%
df['metric_value'] = df['metric_value']/1000000

# %%
# Пример данных за один день
df[df['time_at'] == '2025-09-01'].sort_values(by=['country', 'metric_value'], ascending=False)

# %%
df_amount_total = df[(df['platform'] == 'total') & (df['country'] == 'total')] # выделим только те разрезы метрики которые нам нужны для расчета

# %%
# Пример данных за один день для расчетной метрики
df_amount_total[df_amount_total['time_at'] == '2025-09-01'].sort_values(by=['country', 'metric_value'], ascending=False)

# %% [markdown]
# ## Аномалии

# %%
# !!! Это пример плоного конфига, его можно передать ниже в функцию для арсчет analyze_latest_point


# p = AnomalyParams(
#     # --- Базовое ---
#     granularity="daily",          # "daily" (дни) или "hourly" (часы). На чувствительность напрямую не влияет
#                                   # но определяет, какие seasonality/окна будут использоваться

#     # --- CI/Z по MAD (история и пороги) ---
#     ci_k=4,                       # Ширина CI: median ± ci_k * σ_MAD
#                                   # МЕНЬШЕ → ЧУВСТВИТЕЛЬНЕЕ (больше алертов по CI)
#                                   # Порядок «покрытия» (если нормальное распр.)
#                                   #   ~1.0 → ≈68% (очень чувствительно)
#                                   #   ~1.5 → ≈86%,
#                                   #   ~1.88 → ≈94%
#                                   #   ~2.0 → ≈95.4% (классика 95%)
#                                   #   ~2.5 → ≈98.8%
#                                   #   ~3.0 → ≈99.73%
#                                   #   ~3.5 → ~99.95%
#                                   #   ~4.0 → ~99.997% (очень широкий, почти всё внутри)
#                                   # Сейчас: 4 → CI максимально широкий, CI-алерты будут редкими

#     z_threshold=4,                # Порог по |z_score| (тот же σ_MAD)
#                                   # МЕНЬШЕ → ЧУВСТВИТЕЛЬНЕЕ (чаще z_alert = 1)
#                                   # Те же уровни «покрытия», что и для ci_k
#                                   # Обычно логично держать z_threshold ≈ ci_k
#                                   # либо чуть ниже (z_threshold < ci_k), если хочешь
#                                   # чтобы z_alert срабатывал раньше, чем CI

#     rolling_window_hourly=24,     # Сколько последних часов использовать как fallback-историю
#                                   # когда не хватает точек в том же bin (часе)
#                                   # МЕНЬШЕ → ближе к локальному поведению (чувствительнее к свежим сдвигам, но шумнее)
#                                   # БОЛЬШЕ → более сглаженная, «длинная» история

#     rolling_window_daily=30,      # Аналогично, но для daily: сколько дней брать в историю
#                                   # 7–14 → очень чувствительно к локальным движухам
#                                   # 30–90 → более стабильная, «долгая» база

#     # --- Advanced CI (источник истории и сглаживание σ) ---
#     ci_use_same_bin=True,         # True → сначала берём историю только по тому же часу/дню недели
#                                   # затем fallback на rolling_window
#                                   # False → всегда rolling_window (менее сезонно-чувствительно, но проще)

#     ci_min_points_same_bin_hourly=3,  # Сколько минимум точек нужно в "том же часе", чтобы считать bin-историю
#                                       # МЕНЬШЕ → легче переключаться на узкую «корзину» (чувствительнее к почасовой сезонности)
#                                       # БОЛЬШЕ → реже используем узкий bin, чаще fallback на общий rolling

#     ci_min_points_same_bin_daily=3,   # То же, но для daily: «тот же день недели»
#                                       # Если метрика сильно по дням недели различается, имеет смысл не делать 1
#                                       # а держать 3–5, чтобы не ловить шум

#     ci_bin_tail_factor=4,             # Сколько последних точек bin брать: min_points * factor
#                                       # МЕНЬШЕ (3–4) → bin-история более локальная (чувствительная)
#                                       # БОЛЬШЕ (6–10) → bin-история сглаженнее

#     ci_smooth_mad_hourly=0,           # Сглаживание σ по времени (часовая гранулярность): 0=выкл
#                                       # >0 → берём rolling mean по σ, уменьшаем «дёргание» CI
#                                       # Обычно 3–7 если σ очень шумная
#                                       # МЕНЬШЕ сглаживание → чувствительнее, но нервнее.

#     ci_smooth_mad_daily=7,            # То же для daily
#                                       # 0 → максимально «живой» σ (больше резких сужений/расширений CI)
#                                       # 7–14 → более гладкий CI (стабильнее, но может чуть «маскировать» резкие всплески σ)

#     ci_std_clip_min=None,             # Нижний клип σ: если поставить, например, 0.01
#                                       # CI никогда не станет совсем узким (полезно при очень низком шуме)
#                                       # Если None → без клипа, можно ловить очень узкие CI

#     ci_std_clip_max=None,             # Верхний клип σ: ограничивает максимально возможную ширину CI
#                                       # МЕНЬШЕ → не даём CI «разъехаться» слишком широко
#                                       # но если переборщить, можно потерять «робастность» к редким большим скачкам
#                                       # Сейчас None → σ не ограничиваем сверху

#     # --- STL (сезонность) ---
#     stl_period_hourly=24 * 7,         # Период сезонности для STL (часовая гранулярность)
#                                       # Обычно 24 (день) или 24*7 (неделя)
#                                       # Если сезонность очевидно недельная → 24*7 ок

#     stl_period_daily=7,               # Период для daily (7 → недельная сезонность)
#                                       # Если почти нет недельной сезонности, можно пробовать None или 1–3
#                                       # но чаще 7 — разумно

#     stl_std_multiplier=2.5,             # Порог по остаткам STL: |resid| > m * std(resid) → stl_alert = 1
#                                       # МЕНЬШЕ (0.8–1.0) → очень чувствительно (почти все выбросы по STL)
#                                       # 1.5–2.0 → средняя чувствительность
#                                       # 2.5–3.0 → только сильные выбросы.

#     # --- SESD / Seasonal ESD (последняя точка) ---
#     sesd_alpha=0.05,                  # Уровень значимости Grubbs/ESD
#                                       # БОЛЬШЕ (0.15–0.25) → легче признать точку аномальной (чувствительнее)
#                                       # МЕНЬШЕ (0.01–0.05) → строже (меньше SESD-алертов)
#                                       # Сейчас 0.07 → ближе к строгому, но не ультра

#     seasonality_hourly=24 * 7,        # Длина сезонности для SESD (hourly)
#                                       # Обычно совпадает с STL-периодом

#     seasonality_daily=7,              # Длина сезонности для SESD (daily)
#                                       # 7 → недельный паттерн. Можно менять, если есть другая сезонность

#     sesd_window_hourly=24,            # Reference-окно для сравнения с прошлым сезоном (hourly)
#                                       # МЕНЬШЕ → более локальная чувствительность
#                                       # БОЛЬШЕ → усреднённый baseline

#     sesd_window_daily=7,              # То же для daily
#                                       # 5–7 → «окно недели». Если сделаешь 14–21 → baseline более сглаженный

#     sesd_ppd_hourly=24,               # Points-per-day для hourly (для trend_window и проч.)
#                                       # Обычно 24, менять редко нужно

#     sesd_ppd_daily=1,                 # Points-per-day для daily
#                                       # 1 → тренд по дням
#                                       # 7 → можно строить тренд по неделям (если перепишешь логику)

#     sesd_hybrid=True,                 # True → гибридный MAD+z (робастнее к выбросам)
#                                       # False → классический zscore по std

#     # --- LOF / Isolation Forest (глобальные выбросы) ---
#     contamination_threshold=0.02,     # Ожидаемая доля выбросов для IsolationForest
#                                       # МЕНЬШЕ (0.02–0.05) → модель считает, что выбросов мало → флагов меньше, НО более «жирные»
#                                       # БОЛЬШЕ (0.1–0.2) → будет маркировать больше точек как выбросы

#     lof_contamination=0.02,           # То же для LOF
#                                       # Обычно держать в том же диапазоне, что и contamination_threshold

#     lof_neighbors_hourly=20,          # Кол-во соседей для LOF (hourly)
#                                       # МЕНЬШЕ (5–10) → чувствительнее к локальным выбросам
#                                       # БОЛЬШЕ (20–50) → более глобальная структура, менее нервно

#     lof_neighbors_daily=20,           # То же для daily
#                                       # 10–20 — хороший рабочий диапазон

#     # --- CUSUM (сдвиг среднего) ---
#     cusum_k=0.5,                      # Ожидаемый сдвиг среднего в σ
#                                       # МЕНЬШЕ (0.25–0.5) → замечаем даже маленькие сдвиги (чувствительнее)
#                                       # БОЛЬШЕ (0.75–1.0) → только крупные

#     cusum_h=5,                        # Порог накопленной статистики
#                                       # МЕНЬШЕ (3–4) → чаще срабатывает
#                                       # БОЛЬШЕ (6–8) → только устойчивые длинные сдвиги

#     cusum_reference_window=56,        # Окно базовой выборки (для оценки mean/std), в точках
#                                       # Для daily: 28–90 (1–3 месяца) — типичный диапазон

#     # --- Переключатели методов ---
#     enable_sesd=True,                 # Включить SESD (последняя точка с учётом сезонности)
#     enable_stl=True,                  # Включить STL (сигнал по residuals)
#     enable_iforest=True,              # Включить IsolationForest
#     enable_lof=True,                  # Включить LOF
#     enable_cusum=False,               # Включить CUSUM (если хочешь ловить долгие сдвиги тренда)
# )

# %%
# За какой период считать
start_date = datetime(2025, 9, 1)
end_date = datetime(2025, 11, 11) 

daily_dates = [start_date + timedelta(days=i) for i in range((end_date - start_date).days + 1)]

df_anomaly = pd.DataFrame()

for date_str in tqdm(daily_dates):
    
    pre_df = df_amount_total[(df_amount_total['time_at'] <= date_str) & (df_amount_total['time_at'] >= date_str - pd.Timedelta(days=30))] # показыаем не весь датасет, а можно весь. Тестируй
    
    result_pre = analyze_latest_point(
                    df_two_cols=pre_df[["time_at", "metric_value"]],
                    metric_name="amount",
                    granularity="daily",
                    # params=p # Если передаешь конфиг
                    sensitivity=1, # 1-6, где 1 очень чувствиательно, 6 - очень нечувствиутельно, если передал конфиг, убери это от сюда
                    enable_cusum=False   # переопределяем флаг
    )

    
    df_anomaly = pd.concat([df_anomaly, result_pre])

# %%
# Получили аномалии и всякие разные статистики для контроля
df_anomaly.head()

# %% [markdown]
# ### График аномалий

# %%
import plotly.io as pio
import plotly.graph_objects as go
from plotly.subplots import make_subplots

pio.renderers.default = "notebook"


x_tick_format = '%Y-%m-%d'

fig = make_subplots(specs=[[{"secondary_y": False}]])
fig.add_trace(go.Scatter(
    x=df_anomaly['time_at'],
    y=df_anomaly['metric_value'],
    mode='lines',
    name='Метрика',
    line=dict(color='black')
))

fig.add_trace(go.Scatter(
    x=df_anomaly['time_at'],
    y=df_anomaly['ci_upper'],
    mode='lines',
    name='CI Верх',
    line=dict(dash='dot', color='red')
))
fig.add_trace(go.Scatter(
    x=df_anomaly['time_at'],
    y=df_anomaly['ci_lower'],
    mode='lines',
    name='CI Низ',
    line=dict(dash='dot', color='blue')
))

markers = {
    'ci_alert': ('▲', 'darkorange'),
    'z_alert': ('■', 'green'),
    'iforest_alert': ('♦', 'purple'),
    'lof_alert': ('✖', 'brown'),
    'stl_alert': ('▣', 'blue'),
    'sesd_alert': ('⬢', 'magenta'),
    'cusum_alert': ('⬢', 'black'),
    'anomaly_final': ('★', 'red')
}

for method, (symbol, color) in markers.items():
    sub = df_anomaly[df_anomaly[method] == 1]
    fig.add_trace(go.Scatter(
        x=sub['time_at'],
        y=sub['metric_value'],
        mode='markers',
        name=method,
        marker=dict(symbol='circle', size=9, color=color),
        text=[method] * len(sub)
    ))

fig.update_layout(
    title='Обнаружение аномалий',
    xaxis_title='Дата',
    yaxis_title='Значение метрики',
    template='plotly_white',
    xaxis=dict(
        tickformat=x_tick_format,
        tickangle=45
    ),
    width=1800,
    height=450
)

fig.update_yaxes(range=[0, df_anomaly['ci_upper'].max() * 1.2])

fig.show()

# %% [markdown]
# ## Декомпозиция метрик

# %%
dims = ["country", "platform"]

df_final_impact_anomalys = attach_multi_impact(
    df_anomaly=df_anomaly,         # датафрейм с аномалиями; содержит time_col_anom и anomaly_flag_col
    df=df,                         # полный исходный датафрейм с метриками и измерениями («факты»)
    dims=dims,                     # список измерений, по которым считать вклад пример: ["country", "platform", "device"]
    time_col="time_at",            # колонка в df, где лежит timestamp метрики
    metric_col="metric_value",     # колонка в df, по которой считаем вклад (сама метрика)
    total_value="total",           # значение, означающее «агрегатный уровень» для измерений например: platform == "total" → это общий уровень
    time_col_anom="time_at",       # колонка в df_anomaly со временем аномалии
    anomaly_flag_col="anomaly_final", # бинарный флаг: 1  тут есть аномалия
    window_days=5,                 # за сколько предыдущих дней усреднять baseline = среднее по N предыдущим датам
    top_k=3,                       # сколько топ-групп включать в текст импакта
    exclude_groups=("total", "-"), # какие группы игнорировать в расчётах (регистр неважен) total, или как называется у вас в данных
    prefix="impact_text_",         # префикс названия итоговых текстовых колонок результатами будут: impact_text_country, impact_text_platform, ...
    decimals_value=2,              # числа после запятой для метрики
    decimals_pct=0,                # числа после запятой для процентов
)

# %%
df_final_impact_anomalys[df_final_impact_anomalys['anomaly_final'] == 1].tail(1)

# %% [markdown]
# ## Прогноз

# %%
# Только эти даты буду расчитаны
targets = pd.date_range("2025-10-23", "2025-10-24", freq="D")

cfg = BFConfig(
    time_col="time_at",              # Имя колонки с датой/временем
    value_col="metric_value",        # Имя колонки со значением метрики

    granularity="daily",             # Тип данных: daily или hourly (влияет на сезонность, STEP, naive)

    targets=targets,                 # Список дат, для которых надо сделать прогноз (точечные прогнозы)

    winsorize=True,                  # Робастное обрезание выбросов по сезонным корзинам
    winsor_k=4.0,                    # Насколько сильно обрезать выбросы: медиана ± k*MAD

    holidays_country="RU",           # Страна для генерации праздничных дат (влияет на модель Prophet)
    seasonality_mode="multiplicative", # Режим сезонности Prophet: additive / multiplicative
    interval_width=0.8,              # Ширина доверительного интервала (влияет на неопределённость)
    uncertainty_samples=0,           # 0 = отключить сэмплирование неопределённости (ускоряет)
    changepoint_prior_scale=0.1,     # Насколько гибкие изменения тренда (меньше → более гладко)
    seasonality_prior_scale=10.0,    # Насколько активно сезонность может подстраиваться
    yearly=True,                     # Учёт годовой сезонности (только для daily)
    weekly=True,                     # Учёт недельной сезонности
    add_monthly_for_daily=True,      # Добавлять ли кастомную месячную сезонность (каждые ~30.5 дней)

    ets_trend="add",                 # Тип тренда: add, mul или None
    ets_seasonal_daily="add",        # Тип сезонности для daily ETS: add/mul/None
    ets_seasonal_hourly="add",       # Тип сезонности для hourly ETS

    min_points_prophet=28,           # Минимальное количество точек для запуска Prophet
    min_points_ets=28,               # Минимальное количество точек для ETS (или fallback → naive)
    backtest_window_daily=28,        # Окно бэктеста для подбора весов моделей (daily)
    backtest_window_hourly=24*7,     # Окно бэктеста для hourly (7 дней * 24 часа)

    log_y="auto",                    # Лог-трансформация: True/False/auto
    log_cv_threshold=0.3,            # Если CV(метрики) > threshold → auto включает лог-трансформацию

    seed=42,                         # Random seed
)

fc_df = forecast_values_for_targets_better(df_amount_total, cfg=cfg) # передаем исходный датасет, где срез под нашу мтерику

df_final_impact_anomalys_fc = df_final_impact_anomalys.merge(fc_df, on="time_at", how="left")

# %%
df_final_impact_anomalys_fc[(df_final_impact_anomalys_fc['time_at'] >= '2025-10-23') & (df_final_impact_anomalys_fc['time_at'] <= '2025-10-24')]

# %% [markdown]
# ## Сообщение в чат

# %% [markdown]
# ### VKteams

# %%
import os

# %%
token=os.getenv("VKTEAMS_BOT_TOKEN", "").strip()
chat_id="user@example.com"

# %% [markdown]
# #### Полный конфиг для настройки сообщения

# %%
cfg = AlertConfig(
    # ===== Колонки во входном датафрейме =====
    time_col="time_at",                 # колонка со временем точки/аномалии
    value_col="metric_value",           # колонка со значением метрики
    anomaly_col="anomaly_final",        # колонка с флагом аномалии: 1 = аномалия
    metric_name_col="metric_name",      # колонка с названием метрики
    granularity_col="granularity",      # колонка с гранулярностью ряда: daily / hourly

    # ===== Старый формат импактов (для обратной совместимости) =====
    impact_bu_col="impact_text_bu",     # старая колонка с текстом импакта по продуктам
    impact_platform_col="impact_text_platform",  # старая колонка с текстом импакта по платформам
    impact_bu_heading="Изменение за счет продуктов:",   # заголовок для старого блока продуктов
    impact_platform_heading="Изменение за счет площадок:",  # заголовок для старого блока платформ

    # ===== Новый формат импакт-блоков =====
    impact_blocks=[
        ("Изменения за счёт Age Group:", "impact_text_age_group"),   # (заголовок блока, имя колонки с текстом)
        ("Изменения за счёт Стран:", "impact_text_country"),         # можно передать 1..N блоков
        ("Изменения за счёт Платформ:", "impact_text_platform"),
    ],

    # ===== Прогноз =====
    forecast_col="forecast",            # основная колонка с финальным прогнозом
    forecast_alt_cols=(
        "forecast_prophet",             # прогноз от Prophet
        "forecast_ets",                 # прогноз от ETS
        "forecast_naive",               # прогноз от naive
    ),
    forecast_weight_cols=(
        "w_prophet",                    # вес Prophet
        "w_ets",                        # вес ETS
        "w_naive",                      # вес naive
    ),

    # ===== Окно и размер графика =====
    plot_window_points=60,              # сколько последних точек показывать на графике
    figure_size=(15, 6),                # размер графика matplotlib: (ширина, высота)

    # ===== Форматирование чисел в тексте =====
    value_decimals=2,                   # сколько знаков после запятой показывать у значения метрики
    pct_decimals=0,                     # сколько знаков после запятой показывать у процентов (DoD, WoW, vs avg)
    forecast_decimals=2,                # сколько знаков после запятой показывать у прогноза; если None -> value_decimals
    diff_decimals=2,                    # сколько знаков после запятой показывать у diff; если None -> value_decimals

    # ===== Настройки оси X =====
    x_major_freq=2,                     # шаг основных тиков по X: например 2 = каждые 2 дня/часа/недели
    x_major_unit="day",                 # единица основных тиков: day / hour / week / month
    x_minor_freq=None,                  # шаг minor ticks по X; None = не использовать
    x_minor_unit=None,                  # единица minor ticks: day / hour / week / month
    x_date_format_daily="%Y-%m-%d",     # формат подписей даты для daily рядов
    x_date_format_hourly="%Y-%m-%d %H:%M",  # формат подписей даты для hourly рядов
    x_tick_rotation=90,                 # угол поворота подписей оси X

    # ===== Настройки оси Y =====
    y_min=0,                            # нижняя граница оси Y; None = авто
    y_max=None,                         # верхняя граница оси Y; None = авто
    y_tick_step=50000,                  # шаг тиков оси Y; None = авто
    y_label_decimals=1,                 # сколько знаков после запятой показывать у подписей оси Y
    y_use_compact_unit=True,            # использовать ли масштабирование тыс / млн / млрд

    # ===== Подписи осей =====
    x_label="Дата",                     # подпись оси X
    y_label="Amount",                   # подпись оси Y

    # ===== Заголовок графика =====
    plot_title_prefix="Аномалии",       # префикс в заголовке графика, будет: "Аномалии amount"

    # ===== Сетка графика =====
    grid_enabled=True,                  # включить/выключить сетку
    grid_linestyle="--",                # стиль линий сетки
    grid_linewidth=0.5,                 # толщина линий сетки
    grid_alpha=0.7,                     # прозрачность сетки

    # ===== Легенда =====
    legend_loc="upper left",            # положение легенды на графике

    # ===== Подписи срезов в тексте сообщения =====
    slice1_name="Страна",               # название первого среза
    slice1_value="Total",               # значение первого среза
    slice2_name="Платформа",            # название второго среза
    slice2_value="Total",               # значение второго среза

    # ===== Ссылки внизу сообщения =====
    links=[
        ("Дашборд по аномалиям", "https://mydashboard.com"),   # (текст ссылки, URL)
        ("Факторный анализ", "https://mydashboard-factor.com"),
    ],

    # ===== API VK Teams =====
    vkteams_api_url="https://api.internal.myteam.mail.ru/bot/v1",  # базовый URL API VK Teams

    # ===== Логика отправки =====
    anomaly_only=True,                  # если True — отправлять только когда anomaly_final == 1

    # ===== Шаблон сообщения =====
    message_style="extended_inline",    # стиль сообщения:
                                        # "standard"         — базовый текущий формат
                                        # "extended_inline"  — базовый формат + сравнение со средним за N дней
                                        # "analytic_blocks"  — более структурный формат блоками

    # ===== Сравнение со средним за N дней =====
    show_avg_compare=True,              # добавлять ли сравнение с средним за N предыдущих дней
    avg_compare_days=7,                 # за сколько предыдущих дней считать среднее
    avg_compare_label="vs avg 7d",      # как подписывать это сравнение в сообщении

    # ===== Разделитель между блоками импакта =====
    impact_join_separator="\n\n",       # что вставлять между блоками факторов; "\n\n" = пустая строка между блоками
)

# %% [markdown]
# #### Вариант 1 - сообщения, без настроек

# %%
df_final = df_final_impact_anomalys_fc[df_final_impact_anomalys_fc['time_at'] <= '2025-10-23']
df_final["responsibles_text"] = (
    "@[user1@example.com], "
    "@[user2@example.com], "
    "@[user3@example.com], "
    "@[user4@example.com]"
)

# %%
# Вариант 1 - сообщения, без настроек

cfg = AlertConfig(
    plot_window_points=60,
    slice1_name="Страна", slice1_value="Total",
    slice2_name="Платформа", slice2_value="Total",
    impact_blocks=[
        ("Изменения за счёт Age Group:", "impact_text_age_group"),
        ("Изменения за счёт Стран:", "impact_text_country"),
        ("Изменения за счёт Платформ:", "impact_text_platform"),
        ("Ответственные за первичный разбор:", "responsibles_text"),
    ],
    links=[("Дашборд по аномалиям", "https://mydashboard.com")]
)

resp = send_alert_for_date(
    df_final=df_final,       # откуда берем данные
    now=pd.Timestamp("2025-10-23"),
    metric_name="amount",                 # опционально, иначе возьмётся из столбца metric_name
    token=token,
    chat_id=chat_id,
    cfg=cfg,
    also_return=True
)

# вывод того что отправляет для информаци
if resp:
    print("Caption:\n", resp["caption"][:500], "...")
    print("Image path:", resp["image_path"])
    print("VKTeams:", resp["send_result"])
else:
    print("На указанную дату либо строки нет, либо нет аномалии (cfg.anomaly_only=True).")

# %% [markdown]
# #### Вариант 1 - с настройкой осей и форматом числе

# %%
cfg = AlertConfig(
    plot_window_points=60,

    slice1_name="Страна",
    slice1_value="Total",
    slice2_name="Платформа",
    slice2_value="Total",

    impact_blocks=[
        ("Изменения за счёт Age Group:", "impact_text_age_group"),
        ("Изменения за счёт Стран:", "impact_text_country"),
        ("Изменения за счёт Платформ:", "impact_text_platform"),
    ],

    links=[("Дашборд по аномалиям", "https://mydashboard.com")],

    # формат чисел
    value_decimals=4,
    pct_decimals=1,
    forecast_decimals=4,
    diff_decimals=2,

    # ось X
    x_major_unit="day",
    x_major_freq=2,
    x_date_format_daily="%Y-%m-%d",
    x_tick_rotation=90,

    # ось Y
    y_min=0.4,
    y_max=None,
    y_tick_step=0.05,
    y_label_decimals=2,
    y_use_compact_unit=True,

    # подписи
    x_label="Дата",
    y_label="Amount",

    # оформление
    legend_loc="upper left",
    grid_enabled=True,
)


resp = send_alert_for_date(
    df_final=df_final_impact_anomalys_fc[df_final_impact_anomalys_fc['time_at'] <= '2025-10-23'],       # откуда берем данные
    now=pd.Timestamp("2025-10-23"),
    metric_name="amount",                 # опционально, иначе возьмётся из столбца metric_name
    token=token,
    chat_id=chat_id,
    cfg=cfg,
    also_return=True
)

# вывод того что отправляет для информаци
if resp:
    print("Caption:\n", resp["caption"][:500], "...")
    print("Image path:", resp["image_path"])
    print("VKTeams:", resp["send_result"])
else:
    print("На указанную дату либо строки нет, либо нет аномалии (cfg.anomaly_only=True).")

# %% [markdown]
# #### Вариант 2 - Со сравнением со средним за N дней

# %%
cfg = AlertConfig(
    message_style="extended_inline",
    show_avg_compare=True,
    avg_compare_days=7,
    avg_compare_label="vs avg 7d",
    plot_window_points=60,
    impact_blocks=[
        ("Изменения за счёт Age Group:", "impact_text_age_group"),
        ("Изменения за счёт Стран:", "impact_text_country"),
        ("Изменения за счёт Платформ:", "impact_text_platform"),
    ],
    links=[("Дашборд по аномалиям", "https://mydashboard.com")],
)


resp = send_alert_for_date(
    df_final=df_final_impact_anomalys_fc[df_final_impact_anomalys_fc['time_at'] <= '2025-10-23'],       # откуда берем данные
    now=pd.Timestamp("2025-10-23"),
    metric_name="amount",                 # опционально, иначе возьмётся из столбца metric_name
    token=token,
    chat_id=chat_id,
    cfg=cfg,
    also_return=True
)

# вывод того что отправляет для информаци
if resp:
    print("Caption:\n", resp["caption"][:500], "...")
    print("Image path:", resp["image_path"])
    print("VKTeams:", resp["send_result"])
else:
    print("На указанную дату либо строки нет, либо нет аномалии (cfg.anomaly_only=True).")

# %% [markdown]
# ### Telegram

# %%
token=""
chat_id=""

# %% [markdown]
# #### Полный конфиг для настройки сообщения

# %%
cfg_tg = AlertConfig_tg(
    # ===== Колонки во входном датафрейме =====
    time_col="time_at",                 # колонка со временем точки/аномалии
    value_col="metric_value",           # колонка со значением метрики
    anomaly_col="anomaly_final",        # колонка с флагом аномалии: 1 = аномалия
    metric_name_col="metric_name",      # колонка с названием метрики
    granularity_col="granularity",      # колонка с гранулярностью ряда: daily / hourly

    # ===== Новый формат импакт-блоков =====
    impact_blocks=[
        ("Изменения за счёт Age Group:", "impact_text_age_group"),   # (заголовок блока, имя колонки с текстом)
        ("Изменения за счёт Стран:", "impact_text_country"),         # можно передать 1..N блоков
        ("Изменения за счёт Платформ:", "impact_text_platform"),
    ],

    # ===== Прогноз =====
    forecast_col="forecast",            # основная колонка с финальным прогнозом
    forecast_alt_cols=(
        "forecast_prophet",             # прогноз от Prophet
        "forecast_ets",                 # прогноз от ETS
        "forecast_naive",               # прогноз от naive
    ),
    forecast_weight_cols=(
        "w_prophet",                    # вес Prophet
        "w_ets",                        # вес ETS
        "w_naive",                      # вес naive
    ),

    # ===== Окно и размер графика =====
    plot_window_points=60,              # сколько последних точек показывать на графике
    figure_size=(15, 6),                # размер графика matplotlib: (ширина, высота)

    # ===== Форматирование чисел в тексте =====
    value_decimals=2,                   # сколько знаков после запятой показывать у значения метрики
    pct_decimals=0,                     # сколько знаков после запятой показывать у процентов (DoD, WoW, vs avg)
    forecast_decimals=2,                # сколько знаков после запятой показывать у прогноза; если None -> value_decimals
    diff_decimals=2,                    # сколько знаков после запятой показывать у diff; если None -> value_decimals

    # ===== Настройки оси X =====
    x_major_freq=2,                     # шаг основных тиков по X: например 2 = каждые 2 дня/часа/недели
    x_major_unit="day",                 # единица основных тиков: day / hour / week / month
    x_minor_freq=None,                  # шаг minor ticks по X; None = не использовать
    x_minor_unit=None,                  # единица minor ticks: day / hour / week / month
    x_date_format_daily="%Y-%m-%d",     # формат подписей даты для daily рядов
    x_date_format_hourly="%Y-%m-%d %H:%M",  # формат подписей даты для hourly рядов
    x_tick_rotation=90,                 # угол поворота подписей оси X

    # ===== Настройки оси Y =====
    y_min=0,                            # нижняя граница оси Y; None = авто
    y_max=None,                         # верхняя граница оси Y; None = авто
    y_tick_step=50000,                  # шаг тиков оси Y; None = авто
    y_label_decimals=1,                 # сколько знаков после запятой показывать у подписей оси Y
    y_use_compact_unit=True,            # использовать ли масштабирование тыс / млн / млрд

    # ===== Подписи осей =====
    x_label="Дата",                     # подпись оси X
    y_label="Amount",                   # подпись оси Y

    # ===== Заголовок графика =====
    plot_title_prefix="Аномалии",       # префикс в заголовке графика, будет: "Аномалии · amount"

    # ===== Сетка графика =====
    grid_enabled=True,                  # включить/выключить сетку
    grid_linestyle="--",                # стиль линий сетки
    grid_linewidth=0.5,                 # толщина линий сетки
    grid_alpha=0.7,                     # прозрачность сетки

    # ===== Легенда =====
    legend_loc="upper left",            # положение легенды на графике

    # ===== Подписи срезов в тексте сообщения =====
    slice1_name="Страна",               # название первого среза
    slice1_value="Total",               # значение первого среза
    slice2_name="Платформа",            # название второго среза
    slice2_value="Total",               # значение второго среза

    # ===== Ссылки внизу сообщения =====
    links=[
        ("Дашборд по аномалиям", "https://mydashboard.com"),   # (текст ссылки, URL)
        ("Факторный анализ", "https://mydashboard-factor.com"),
    ],

    # ===== Логика отправки =====
    anomaly_only=True,                  # если True — отправлять только когда anomaly_final == 1

    # ===== Шаблон сообщения =====
    message_style="extended_inline",    # стиль сообщения:
                                        # "standard"         — базовый текущий формат
                                        # "extended_inline"  — базовый формат + сравнение со средним за N дней
                                        # "analytic_blocks"  — более структурный формат блоками

    # ===== Сравнение со средним за N дней =====
    show_avg_compare=True,              # добавлять ли сравнение с средним за N предыдущих дней
    avg_compare_days=7,                 # за сколько предыдущих дней считать среднее
    avg_compare_label="vs avg 7d",      # как подписывать это сравнение в сообщении

    # ===== Разделитель между блоками импакта =====
    impact_join_separator="\n\n",       # что вставлять между блоками факторов; "\n\n" = пустая строка между блоками
)

# %% [markdown]
# #### Вариант 1 - сообщения, без настроек

# %%
# Вариант 1 - сообщения, без настроек

cfg = AlertConfig_tg(
    plot_window_points=60,
    slice1_name="Страна", slice1_value="Total",
    slice2_name="Платформа", slice2_value="Total",
    impact_blocks=[
        ("Изменения за счёт Age Group:", "impact_text_age_group"),
        ("Изменения за счёт Стран:", "impact_text_country"),
        ("Изменения за счёт Платформ:", "impact_text_platform"),
    ],
    links=[("Дашборд по аномалиям", "https://mydashboard.com")]
)

resp = send_alert_for_date_tg(
    df_final=df_final_impact_anomalys_fc[df_final_impact_anomalys_fc['time_at'] <= '2025-10-23'],
    now=pd.Timestamp("2025-10-23"),
    metric_name="Amount",
    token=token,
    chat_id=chat_id,
    cfg=cfg_tg,
    also_return=True
)


# вывод того что отправляет для информаци
if resp:
    print("Caption:\n", resp["caption"][:500], "...")
    print("Image path:", resp["image_path"])
    # print("Tg:", resp["send_result"])
else:
    print("На указанную дату либо строки нет, либо нет аномалии (cfg.anomaly_only=True).")

# %% [markdown]
# #### Вариант 1 - с настройкой осей и форматом числе

# %%
cfg = AlertConfig_tg(
    plot_window_points=60,

    slice1_name="Страна",
    slice1_value="Total",
    slice2_name="Платформа",
    slice2_value="Total",

    impact_blocks=[
        ("Изменения за счёт Age Group:", "impact_text_age_group"),
        ("Изменения за счёт Стран:", "impact_text_country"),
        ("Изменения за счёт Платформ:", "impact_text_platform"),
    ],

    links=[("Дашборд по аномалиям", "https://mydashboard.com")],

    # формат чисел
    value_decimals=4,
    pct_decimals=1,
    forecast_decimals=4,
    diff_decimals=2,

    # ось X
    x_major_unit="day",
    x_major_freq=2,
    x_date_format_daily="%Y-%m-%d",
    x_tick_rotation=90,

    # ось Y
    y_min=0.4,
    y_max=None,
    y_tick_step=0.05,
    y_label_decimals=2,
    y_use_compact_unit=True,

    # подписи
    x_label="Дата",
    y_label="Amount",

    # оформление
    legend_loc="upper left",
    grid_enabled=True,
)


resp = send_alert_for_date_tg(
    df_final=df_final_impact_anomalys_fc[df_final_impact_anomalys_fc['time_at'] <= '2025-10-23'],       # откуда берем данные
    now=pd.Timestamp("2025-10-23"),
    metric_name="amount",                 # опционально, иначе возьмётся из столбца metric_name
    token=token,
    chat_id=chat_id,
    cfg=cfg,
    also_return=True
)

# вывод того что отправляет для информаци
if resp:
    print("Caption:\n", resp["caption"][:500], "...")
    print("Image path:", resp["image_path"])
    # print("Tg:", resp["send_result"])
else:
    print("На указанную дату либо строки нет, либо нет аномалии (cfg.anomaly_only=True).")

# %% [markdown]
# #### Вариант 2 - Со сравнением со средним за N дней

# %%
cfg = AlertConfig_tg(
    message_style="extended_inline",
    show_avg_compare=True,
    avg_compare_days=7,
    avg_compare_label="vs avg 7d",
    plot_window_points=60,
    impact_blocks=[
        ("Изменения за счёт Age Group:", "impact_text_age_group"),
        ("Изменения за счёт Стран:", "impact_text_country"),
        ("Изменения за счёт Платформ:", "impact_text_platform"),
    ],
    links=[("Дашборд по аномалиям", "https://mydashboard.com")],
)


resp = send_alert_for_date_tg(
    df_final=df_final_impact_anomalys_fc[df_final_impact_anomalys_fc['time_at'] <= '2025-10-23'],       # откуда берем данные
    now=pd.Timestamp("2025-10-23"),
    metric_name="amount",                 # опционально, иначе возьмётся из столбца metric_name
    token=token,
    chat_id=chat_id,
    cfg=cfg,
    also_return=True
)

# вывод того что отправляет для информаци
if resp:
    print("Caption:\n", resp["caption"][:500], "...")
    print("Image path:", resp["image_path"])
    # print("Tg:", resp["send_result"])
else:
    print("На указанную дату либо строки нет, либо нет аномалии (cfg.anomaly_only=True).")
